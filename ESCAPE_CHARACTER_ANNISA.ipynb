# %% [markdown]
# <a href="https://colab.research.google.com/github/kholifah244/Tugas-Computer-Programming-2/blob/main/ESCAPE_CHARACTER_ANNISA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Dia berkata: "bertahan!" ')
# Out:
# Dia berkata: "bertahan!"

# %%
print ("Aku menimpali : \"Apakah kau ingin aku 'bertahan'?\"")
# Out:
# Aku menimpali : "Apakah kau ingin aku 'bertahan'?"

# %%
print ('\\(^_^) / (\\-_-//)')
# Out:
# \(^_^) / (\-_-//)
